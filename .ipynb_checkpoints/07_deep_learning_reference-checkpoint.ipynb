# %% [markdown]
# ## Deep Learning Quick Reference

# %% [markdown]
# ### Linear Regression using Keras

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Reading in and plotting
df = pd.read_csv('./data/weight-height.csv')

# Plotting the Data
df.plot(kind='scatter', x='Height', y='Weight', title='Weight and Height in adults')

# %% [markdown]
# #### Fitting the model with Keras

# %%
from keras.models import Sequential 
from keras.layers import Dense
from keras.optimizers import Adam, SGD

# %%
# Saving the values
X = df[['Height']].values
y_true = df['Weight'].values

# %%
# Sequential Model with one layer

model = Sequential()

# Using the height to predict weight
model.add(Dense(1, input_shape=(1,))) 

# mean squared error is the cost function
model.compile(Adam(lr=0.8), 'mean_squared_error')

# %%
# Fitting
model.fit(X, y_true, epochs=40, verbose=0)

# Predicting
y_pred = model.predict(X)

# %%
# Evaluating
from sklearn.metrics import r2_score

print("The R2 score is {:0.3f}".format(r2_score(y_true, y_pred)))
# Out:
# The R2 score is 0.849

# %% [markdown]
# ### Classification Problem with Keras
# #### Seeing if an employee will leave the company

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Reading in the data
df = pd.read_csv('./data/HR_comma_sep.csv')

# %%
# Normalizing Everything with the Standard Scalar
from sklearn.preprocessing import StandardScaler
from keras.utils import to_categorical

# %%
# Getting Dummies and combining frames
sales = pd.get_dummies(df['sales'], prefix='sales')
salary = pd.get_dummies(df['salary'], prefix='salary')

frames = [df, sales, salary]

# Converting Sales and Salary to Numerical Values 
result = pd.concat(frames, axis=1, sort=False)

# %%
# Train test split
from sklearn.model_selection import train_test_split

# Splitting into X and y
X = result[['satisfaction_level', 'last_evaluation', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years', 'sales_hr', 'sales_management', 
               'sales_marketing', 'sales_product_mng', 'sales_sales', 'sales_support', 'sales_technical', 'salary_high', 'salary_low', 'salary_medium']]
y = result['left']

# Normalizing the average monthly hours
ss = StandardScaler()

X['average_montly_hours'] = ss.fit_transform(X[['average_montly_hours']])

# Train Test Split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
# Building the model
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

model = Sequential()
model.add(Dense(32, input_shape=(16,), activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(Adam(lr=0.05),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=20, verbose=0) # , validation_split=0.1

# %%
# Results
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score

# Predicting
y_pred = model.predict_classes(X_test) 

print(classification_report(y_test, y_pred))
# Out:
# WARNING:tensorflow:From <ipython-input-15-b3e5835534f0>:6: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96      2853
#            1       0.89      0.86      0.87       897
#
#     accuracy                           0.94      3750
#    macro avg       0.92      0.91      0.92      3750
# weighted avg       0.94      0.94      0.94      3750

# %%
print(accuracy_score(y_test, y_pred))
# Out:
# 0.94

# %% [markdown]
# #### Multiclass Classification Problem

# %%
df = pd.read_csv('./data/wines.csv')
df.head(3)
# Out:
#    Class  Alcohol  Malic_acid   Ash  Alcalinity_of_ash  Magnesium  \
# 0      1    14.23        1.71  2.43               15.6        127
# 1      1    13.20        1.78  2.14               11.2        100
# 2      1    13.16        2.36  2.67               18.6        101
#
#    Total_phenols  Flavanoids  Nonflavanoid_phenols  Proanthocyanins  \
# 0           2.80        3.06                  0.28             2.29
# 1           2.65        2.76                  0.26             1.28
# 2           2.80        3.24                  0.30             2.81
#
#    Color_intensity   Hue  OD280-OD315_of_diluted_wines  Proline
# 0             5.64  1.04                          3.92     1065
# 1             4.38  1.05                          3.40     1050
# 2             5.68  1.03                          3.17     1185

# %%
# Good plotting technique
_=df.hist(figsize=(12,10))

# %% [markdown]
# ### Using a correlation plot

# %%
import seaborn as sns

# Correlation Plot
plt.figure(figsize=(9,9))
sns.heatmap(df.corr(), annot=True)

# %% [markdown]
# ## Badass Drop Technique

# %%
# Dividing into X and Y 
X = df.drop('Class', axis=1)
y = df['Class']

# Transforming the Dataset
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
Xsc = sc.fit_transform(X)

# Making sure y is multiple categories
y_cat = pd.get_dummies(y)

# %%
# Importing
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD, Adam, Adadelta, RMSprop
import keras.backend as K

# %%
# Building the Model
K.clear_session()

model = Sequential()
model.add(Dense(32, input_shape=(13,), activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(3, activation='softmax'))
model.compile(Adam(lr=0.1), loss='categorical_crossentropy', metrics=['accuracy']) # Notice Categorical Crossentropy instead of binary

# %% [markdown]
# #### Alternate model

# %%
# K.clear_session()

# model = Sequential()
# model.add(Dense(8, input_shape=(13,), activation='relu'))
# model.add(Dense(5, activation='relu'))
# model.add(Dense(2, activation='tanh'))
# model.add(Dense(3, activation='softmax'))
# model.compile(Adam(lr=0.1),
#               loss='categorical_crossentropy',
#               metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32)                448
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 99
# =================================================================
# Total params: 1,603
# Trainable params: 1,603
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fitting and Evaluating
model.fit(Xsc, y_cat.values, epochs=5, verbose = 1, validation_split=0.3)
# Out:
# Epoch 1/5
# 4/4 [==============================] - 0s 31ms/step - loss: 0.4877 - accuracy: 0.7581 - val_loss: 32.0397 - val_accuracy: 0.1111
# Epoch 2/5
# 4/4 [==============================] - 0s 6ms/step - loss: 0.1017 - accuracy: 0.9597 - val_loss: 73.9631 - val_accuracy: 0.1111
# Epoch 3/5
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2501 - accuracy: 0.9758 - val_loss: 99.9522 - val_accuracy: 0.1111
# Epoch 4/5
# 4/4 [==============================] - 0s 5ms/step - loss: 2.3073e-08 - accuracy: 1.0000 - val_loss: 125.8453 - val_accuracy: 0.1111
# Epoch 5/5
# 4/4 [==============================] - 0s 5ms/step - loss: 5.7863e-06 - accuracy: 1.0000 - val_loss: 148.2915 - val_accuracy: 0.1111

# %% [markdown]
# ### Using the Functional API
# #### Much better performance

# %%
# Another Model

# K.clear_session()

# inputs = Input(shape=(13,))
# x = Dense(8, kernel_initializer='he_normal', activation='tanh')(inputs)
# x = Dense(5, kernel_initializer='he_normal', activation='tanh')(x)
# second_to_last = Dense(2, kernel_initializer='he_normal',
#                        activation='tanh')(x)
# outputs = Dense(3, activation='softmax')(second_to_last)

# model = Model(inputs=inputs, outputs=outputs)

# model.compile(RMSprop(lr=0.05),
#               'categorical_crossentropy',
#               metrics=['accuracy'])

# model.fit(Xsc, y_cat.values, batch_size=16, epochs=20, verbose=1)

# %% [markdown]
# ### Functional API Continued with Tensorboard
# #### Also using early stopping
# #### Validation Data is also passed into the model
#
# #### Need to fix the file paths for Tensorboard (Luke Question)

# %%
from keras.layers import Input
from keras.models import Model

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

# %%
checkpointer = ModelCheckpoint(filepath="/tmp/udemy/weights.hdf5",
                               verbose=1, save_best_only=True)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, TensorBoard

earlystopper = EarlyStopping(monitor='val_loss', min_delta=0,
                             patience=1, verbose=1, mode='auto')

tensorboard = TensorBoard(log_dir='/tmp/udemy/tensorboard/')

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(Xsc, y_cat.values,
                                                    test_size=0.3,
                                                    random_state=42)

# %%
K.clear_session()

inputs = Input(shape=(13,))

x = Dense(8, kernel_initializer='he_normal', activation='tanh')(inputs)
x = Dense(5, kernel_initializer='he_normal', activation='tanh')(x)
second_to_last = Dense(2, kernel_initializer='he_normal',
                       activation='tanh')(x)
outputs = Dense(3, activation='softmax')(second_to_last)

model = Model(inputs=inputs, outputs=outputs)

model.compile(RMSprop(lr=0.05), 'categorical_crossentropy',
              metrics=['accuracy'])

model.fit(X_train, y_train, batch_size=32,
          epochs=20, verbose=2,
          validation_data=(X_test, y_test),
          callbacks=[checkpointer, earlystopper, tensorboard])
# Out:
# Epoch 1/20
# WARNING:tensorflow:Callbacks method `on_train_batch_begin` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_begin` time: 0.0312s). Check your callbacks.
# WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0000s vs `on_train_batch_end` time: 1.6252s). Check your callbacks.
#
# Epoch 00001: val_loss improved from inf to 0.53833, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 2s - loss: 1.0376 - accuracy: 0.5161 - val_loss: 0.5383 - val_accuracy: 0.8889
# Epoch 2/20
#
# Epoch 00002: val_loss improved from 0.53833 to 0.32200, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.4723 - accuracy: 0.9113 - val_loss: 0.3220 - val_accuracy: 0.9630
# Epoch 3/20
#
# Epoch 00003: val_loss improved from 0.32200 to 0.23945, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.2434 - accuracy: 0.9919 - val_loss: 0.2395 - val_accuracy: 0.9630
# Epoch 4/20
#
# Epoch 00004: val_loss improved from 0.23945 to 0.18634, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.1622 - accuracy: 1.0000 - val_loss: 0.1863 - val_accuracy: 0.9815
# Epoch 5/20
#
# Epoch 00005: val_loss improved from 0.18634 to 0.15720, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.1219 - accuracy: 1.0000 - val_loss: 0.1572 - val_accuracy: 0.9815
# Epoch 6/20
#
# Epoch 00006: val_loss improved from 0.15720 to 0.13822, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.0925 - accuracy: 1.0000 - val_loss: 0.1382 - val_accuracy: 0.9815
# Epoch 7/20
#
# Epoch 00007: val_loss improved from 0.13822 to 0.12517, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.0736 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.9815
# Epoch 8/20
#
# Epoch 00008: val_loss improved from 0.12517 to 0.11646, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.0589 - accuracy: 1.0000 - val_loss: 0.1165 - val_accuracy: 0.9815
# Epoch 9/20
#
# Epoch 00009: val_loss improved from 0.11646 to 0.10972, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.0479 - accuracy: 1.0000 - val_loss: 0.1097 - val_accuracy: 0.9815
# Epoch 10/20
#
# Epoch 00010: val_loss improved from 0.10972 to 0.10422, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.0392 - accuracy: 1.0000 - val_loss: 0.1042 - val_accuracy: 0.9815
# Epoch 11/20
#
# Epoch 00011: val_loss improved from 0.10422 to 0.10116, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.0322 - accuracy: 1.0000 - val_loss: 0.1012 - val_accuracy: 0.9815
# Epoch 12/20
#
# Epoch 00012: val_loss improved from 0.10116 to 0.09989, saving model to /tmp/udemy\weights.hdf5
# 4/4 - 0s - loss: 0.0266 - accuracy: 1.0000 - val_loss: 0.0999 - val_accuracy: 0.9815
# Epoch 13/20
#
# Epoch 00013: val_loss did not improve from 0.09989
# 4/4 - 0s - loss: 0.0220 - accuracy: 1.0000 - val_loss: 0.1004 - val_accuracy: 0.9815
# Epoch 00013: early stopping

# %% [markdown]
# ### Opening Tensorboard

# %% [markdown]
# Run Tensorboard with the command:
#
#     tensorboard --logdir /tmp/udemy/tensorboard/
#
# and open your browser at http://localhost:6006

# %% [markdown]
# ## Convolutional Neural Networks

# %% [markdown]
# ### Regular Neural Net Applied to Mnist

# %%
# Loading mnist
from keras.datasets import mnist

(X_train, y_train), (X_test, y_test) = mnist.load_data()

# %%
# Reshaping to flat
X_train = X_train.reshape(-1, 28*28)
X_test = X_test.reshape(-1, 28*28)

# %%
# Converting to floats and rescaling
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')

# Makes its between 0 and 1 instead of 0 and 255
X_train /= 255.0
X_test /= 255.0

# %%
# Converting the 10 outputs to categories
from keras.utils.np_utils import to_categorical

y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %%
# Building the model

K.clear_session()

model = Sequential()
model.add(Dense(512, input_dim=X_train.shape[1], activation='relu'))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(10, activation='softmax'))
model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
# Fitting
h = model.fit(X_train, y_train_cat, batch_size=128, epochs=10, verbose=0, validation_split=0.3)

# %%
# Plot of the results
plt.figure(figsize=(7,5))
plt.plot(h.history['accuracy'])
plt.plot(h.history['val_accuracy'])
plt.legend(['Training', 'Validation'])
plt.title('Accuracy')
plt.xlabel('Epochs')
# Out:
# Text(0.5, 0, 'Epochs')

# %%
test_accuracy = model.evaluate(X_test, y_test_cat)[1]
test_accuracy
# Out:
# 313/313 [==============================] - 0s 1ms/step - loss: 0.1529 - accuracy: 0.9767
# 0.9767000079154968

# %% [markdown]
# ## Neural Net on Mnist

# %%
# Convolutional Layers
from keras.layers import Conv2D

# Pooling Layers
from keras.layers import MaxPool2D, AvgPool2D

# Flattening and Activation
from keras.layers import Flatten, Activation

# %%
# Importing mnist/making sure its in the right shape
from keras.datasets import mnist
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Reshaping
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# Categories of y
y_train_cat = to_categorical(y_train)
y_test_cat = to_categorical(y_test)

# %%
K.clear_session()

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPool2D(pool_size=(2, 2)))

model.add(Flatten())

model.add(Dense(128, activation='relu'))

model.add(Dense(10, activation='softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 26, 26, 32)        320
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 13, 13, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 11, 11, 64)        18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 5, 5, 64)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 1600)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               204928
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                1290
# =================================================================
# Total params: 225,034
# Trainable params: 225,034
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training 
model.fit(X_train, y_train_cat, batch_size=128, epochs=5, verbose=0, validation_split=0.3)

# %%
# Evaluation
model.evaluate(X_test, y_test_cat)[1]
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0651 - accuracy: 0.9851
# 0.9850999712944031

# %% [markdown]
# ## Recurrent Neural Networks on Time Series

# %%
df = pd.read_csv('./data/cansim-0800020-eng-6674700030567901031.csv', skiprows=6, skipfooter=9, engine='python')

# Time series stuff with pandas
from pandas.tseries.offsets import MonthEnd

# Creating a date time object/setting the index
df['Adjustments'] = pd.to_datetime(df['Adjustments']) + MonthEnd(1)
df = df.set_index('Adjustments')

df.plot()

# %%
# Splitting for training and testing (not testing is always after splitting)
split_date = pd.Timestamp('01-01-2011')

train = df.loc[:split_date, ['Unadjusted']]
test = df.loc[split_date:, ['Unadjusted']]

ax = train.plot()
test.plot(ax=ax)
plt.legend(['train', 'test'])

# %%
# Scaling the Data
from sklearn.preprocessing import MinMaxScaler

# Rescaling the data
sc = MinMaxScaler()

train_sc = sc.fit_transform(train)

# Only transform, not fit transform with the test 
test_sc = sc.transform(test)

# %%
# Aiming at the next point with the data
X_train = train_sc[:-1]
y_train = train_sc[1:]

X_test = test_sc[:-1]
y_test = test_sc[1:]

# %%
from keras.layers import LSTM

early_stop = EarlyStopping(monitor='loss', patience=1, verbose=1)

# %%
# Reshaping to Tensors
X_train_t = X_train[:, None]
X_test_t = X_test[:, None]

# %%
K.clear_session()
model = Sequential()

model.add(LSTM(6, input_shape=(1, 1)))

model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

# %%
# Notice the batch size of one
model.fit(X_train_t, y_train, epochs=50, batch_size=0, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 239/239 [==============================] - 0s 783us/step - loss: 0.1031
# Epoch 2/100
# 239/239 [==============================] - 0s 707us/step - loss: 0.0335
# Epoch 3/100
# 239/239 [==============================] - 0s 697us/step - loss: 0.0267
# Epoch 4/100
# 239/239 [==============================] - 0s 697us/step - loss: 0.0209
# Epoch 5/100
# 239/239 [==============================] - 0s 710us/step - loss: 0.0166
# Epoch 6/100
# 239/239 [==============================] - 0s 704us/step - loss: 0.0133
# Epoch 7/100
# 239/239 [==============================] - 0s 727us/step - loss: 0.0115
# Epoch 8/100
# 239/239 [==============================] - 0s 713us/step - loss: 0.0106
# Epoch 9/100
# 239/239 [==============================] - 0s 730us/step - loss: 0.0104 0s - loss: 0.0
# Epoch 10/100
# 239/239 [==============================] - 0s 734us/step - loss: 0.0104
# Epoch 00010: early stopping

# %%
y_pred = model.predict(X_test_t)
plt.figure(figsize=(7,5))
plt.plot(y_test)
plt.plot(y_pred)
plt.legend(['y_test', 'y_pred'])

# %% [markdown]
# ## Creating Windows

# %%
train_sc_df = pd.DataFrame(train_sc, columns=['Scaled'], index=train.index)
test_sc_df = pd.DataFrame(test_sc, columns=['Scaled'], index=test.index)

# Shift function using Pandas 
for s in range(1, 13):
    train_sc_df['shift_{}'.format(s)] = train_sc_df['Scaled'].shift(s)
    test_sc_df['shift_{}'.format(s)] = test_sc_df['Scaled'].shift(s)
    
# Just moving the data by one month. Back in time up to a year.
train_sc_df.head(3)
# Out:
#                Scaled  shift_1  shift_2  shift_3  shift_4  shift_5  shift_6  \
# Adjustments
# 1991-01-31   0.014020      NaN      NaN      NaN      NaN      NaN      NaN
# 1991-02-28   0.000000  0.01402      NaN      NaN      NaN      NaN      NaN
# 1991-03-31   0.070426  0.00000  0.01402      NaN      NaN      NaN      NaN
#
#              shift_7  shift_8  shift_9  shift_10  shift_11  shift_12
# Adjustments
# 1991-01-31       NaN      NaN      NaN       NaN       NaN       NaN
# 1991-02-28       NaN      NaN      NaN       NaN       NaN       NaN
# 1991-03-31       NaN      NaN      NaN       NaN       NaN       NaN

# %%
# Dropping null values and scaled (target)
X_train = train_sc_df.dropna().drop('Scaled', axis=1)
y_train = train_sc_df.dropna()[['Scaled']]

X_test = test_sc_df.dropna().drop('Scaled', axis=1)
y_test = test_sc_df.dropna()[['Scaled']]

# %%
# Creating Numpy Arrays
X_train = X_train.values
X_test= X_test.values

y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# ### Building the LSTM

# %%
# Making tensors for the LSTM
X_train_t = X_train.reshape(X_train.shape[0], 1, 12)
X_test_t = X_test.reshape(X_test.shape[0], 1, 12)

# %%
K.clear_session()
model = Sequential()

model.add(LSTM(6, input_shape=(1, 12)))

model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 6)                 456
# _________________________________________________________________
# dense (Dense)                (None, 1)                 7
# =================================================================
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train_t, y_train, epochs=100, batch_size=1, verbose=1, callbacks=[early_stop])
# Out:
# Epoch 1/100
# 228/228 [==============================] - 0s 786us/step - loss: 0.0767
# Epoch 2/100
# 228/228 [==============================] - 0s 768us/step - loss: 0.0117
# Epoch 3/100
# 228/228 [==============================] - 0s 740us/step - loss: 0.0088
# Epoch 4/100
# 228/228 [==============================] - 0s 753us/step - loss: 0.0073
# Epoch 5/100
# 228/228 [==============================] - 0s 746us/step - loss: 0.0069
# Epoch 6/100
# 228/228 [==============================] - 0s 762us/step - loss: 0.0064
# Epoch 7/100
# 228/228 [==============================] - 0s 779us/step - loss: 0.0060
# Epoch 8/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0053
# Epoch 9/100
# 228/228 [==============================] - 0s 898us/step - loss: 0.0050
# Epoch 10/100
# 228/228 [==============================] - 0s 783us/step - loss: 0.0045
# Epoch 11/100
# 228/228 [==============================] - 0s 770us/step - loss: 0.0041
# Epoch 12/100
# 228/228 [==============================] - 0s 785us/step - loss: 0.0037
# Epoch 13/100
# 228/228 [==============================] - 0s 809us/step - loss: 0.0032
# Epoch 14/100
# 228/228 [==============================] - 0s 803us/step - loss: 0.0028
# Epoch 15/100
# 228/228 [==============================] - 0s 822us/step - loss: 0.0027
# Epoch 16/100
# 228/228 [==============================] - 0s 864us/step - loss: 0.0024
# Epoch 17/100
# 228/228 [==============================] - 0s 835us/step - loss: 0.0021
# Epoch 18/100
# 228/228 [==============================] - 0s 945us/step - loss: 0.0020
# Epoch 19/100
# 228/228 [==============================] - 0s 931us/step - loss: 0.0019
# Epoch 20/100
# 228/228 [==============================] - 0s 1ms/step - loss: 0.0018
# Epoch 21/100
# 228/228 [==============================] - 0s 866us/step - loss: 0.0017
# Epoch 22/100
# 228/228 [==============================] - 0s 943us/step - loss: 0.0015
# Epoch 23/100
# 228/228 [==============================] - 0s 916us/step - loss: 0.0014
# Epoch 24/100
# 228/228 [==============================] - 0s 791us/step - loss: 0.0013
# Epoch 25/100
# 228/228 [==============================] - 0s 987us/step - loss: 0.0013
# Epoch 26/100
# 228/228 [==============================] - 0s 860us/step - loss: 0.0013
# Epoch 27/100
# 228/228 [==============================] - 0s 800us/step - loss: 0.0012
# Epoch 28/100
# 228/228 [==============================] - 0s 783us/step - loss: 0.0012
# Epoch 00028: early stopping

# %%
y_pred = model.predict(X_test_t)
plt.figure(figsize=(7,5))
plt.plot(y_test)
plt.plot(y_pred)
plt.legend(['y_test', 'y_pred'])
