# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_html('https://en.wikipedia.org/wiki/World_War_I_casualties')

# %%
ww1_df = df[0]

# %%
ww1_df.head(20)
# Out:
#                             Nation Population (millions)  \
#                      Allied Powers         Allied Powers
# 0                      Australia a                   5.0
# 1                         Canada d                   7.2
# 2                          India j                 315.1
# 3                    New Zealand o                   1.1
# 4                   Newfoundland p                   0.2
# 5                   South Africa v                   6.0
# 6   United Kingdom(and Colonies) w                  45.4
# 7         British Empire Sub-total                 380.0
# 8                        Belgium b                   7.4
# 9                         Brazil c                  24.2
# 10                         China e                 442.0
# 11                          Cuba f                   2.5
# 12                        France g                  39.6
# 13                        Greece h                   4.8
# ...
